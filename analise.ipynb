# %%
#importanto bibliotecas

import pandas as pd
import matplotlib.pyplot as plt

# %%
#importando a base de dados e visualizando
base = pd.read_csv(r'cancelamentos.csv')
display(base)
# Out:
#         CustomerID  idade    sexo  tempo_como_cliente  frequencia_uso  \
# 0              2.0   30.0  Female                39.0            14.0
# 1              3.0   65.0  Female                49.0             1.0
# 2              4.0   55.0  Female                14.0             4.0
# 3              5.0   58.0    Male                38.0            21.0
# 4              6.0   23.0    Male                32.0            20.0
# ...            ...    ...     ...                 ...             ...
# 881661    449995.0   42.0    Male                54.0            15.0
# 881662    449996.0   25.0  Female                 8.0            13.0
# 881663    449997.0   26.0    Male                35.0            27.0
# 881664    449998.0   28.0    Male                55.0            14.0
# 881665    449999.0   31.0    Male                48.0            20.0
#
#         ligacoes_callcenter  dias_atraso assinatura duracao_contrato  \
# ...

# %%
#verificando informações da base (checando valores nulos)

base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881666 entries, 0 to 881665
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CustomerID              881664 non-null  float64
#  1   idade                   881664 non-null  float64
#  2   sexo                    881664 non-null  object
#  3   tempo_como_cliente      881663 non-null  float64
#  4   frequencia_uso          881663 non-null  float64
#  5   ligacoes_callcenter     881664 non-null  float64
#  6   dias_atraso             881664 non-null  float64
#  7   assinatura              881661 non-null  object
#  8   duracao_contrato        881663 non-null  object
#  9   total_gasto             881664 non-null  float64
#  10  meses_ultima_interacao  881664 non-null  float64
#  11  cancelou                881664 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 80.7+ MB

# %%
#deletando valores nulos e verificando as informações

base =  base.dropna()
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 881659 entries, 0 to 881665
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CustomerID              881659 non-null  float64
#  1   idade                   881659 non-null  float64
#  2   sexo                    881659 non-null  object
#  3   tempo_como_cliente      881659 non-null  float64
#  4   frequencia_uso          881659 non-null  float64
#  5   ligacoes_callcenter     881659 non-null  float64
#  6   dias_atraso             881659 non-null  float64
#  7   assinatura              881659 non-null  object
#  8   duracao_contrato        881659 non-null  object
#  9   total_gasto             881659 non-null  float64
#  10  meses_ultima_interacao  881659 non-null  float64
#  11  cancelou                881659 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 87.4+ MB

# %%
#deletando a coluna CustomerID pois não sera relevante para a analise

base = base.drop(columns='CustomerID')
display(base)
# Out:
#         idade    sexo  tempo_como_cliente  frequencia_uso  \
# 0        30.0  Female                39.0            14.0
# 1        65.0  Female                49.0             1.0
# 2        55.0  Female                14.0             4.0
# 3        58.0    Male                38.0            21.0
# 4        23.0    Male                32.0            20.0
# ...       ...     ...                 ...             ...
# 881661   42.0    Male                54.0            15.0
# 881662   25.0  Female                 8.0            13.0
# 881663   26.0    Male                35.0            27.0
# 881664   28.0    Male                55.0            14.0
# 881665   31.0    Male                48.0            20.0
#
#         ligacoes_callcenter  dias_atraso assinatura duracao_contrato  \
# 0                       5.0         18.0   Standard           Annual
# 1                      10.0          8.0      Basic          Monthly
# ...

# %%
#entendendo total de cancelamentos
print(base['cancelou'].value_counts())
print(base['cancelou'].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# 1.0    499993
# 0.0    381666
# Name: cancelou, dtype: int64
# 1.0    56.7%
# 0.0    43.3%
# Name: cancelou, dtype: object

# %%
#gerando graficos para entender os cancelamentos baseado em cada uma das colunas 

for coluna in base.columns:
    if coluna != "cancelou": 
        plt.figure(figsize=(10, 6))
        for label in base["cancelou"].unique():
            subset = base[base["cancelou"] == label]
            plt.hist(subset[coluna], bins=30, alpha=0.5, label=str(label))

        plt.xlabel(coluna)
        plt.title(f'{coluna} X cancelamento')
        plt.legend(title='Cancelou')
        plt.show()

# %%
#analisando cada grafico, 4 chamam atenção: forma de pagamento, ligações no call center e dias de atraso.
#Notei que todos os clientes que assinavam o plano mensal cancelaram - Clientes que ligam a partir de 5 vezes para call center cancelam  - Clientes que atrasam o pagamento apartir de 21 dias cancelam 

#Removendo da base todos os clientes com o plano mensal 
base = base[base["duracao_contrato"]!="Monthly"]

#Removendo da base todos os clientes com mais de 4 ligações no call center
base = base[base["ligacoes_callcenter"]< 5]

# Removendo da base todos os clientes a partir de 21 dias de atraso no pagamento
base = base[base["dias_atraso"]<=20]

# Removendo da base todos os clientes com de 50 anos
base = base[base["idade"]< 50]

display(base["cancelou"].value_counts())
display(base["cancelou"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# 0.0    364286
# 1.0     50635
# Name: cancelou, dtype: int64
# 0.0    87.8%
# 1.0    12.2%
# Name: cancelou, dtype: object

# %%
# Sugestões:

# Fazendo os ajustes indicados pela analise que são: 
# 1 - Migrar clientes do plano mensal para outros planos e extinguir essa modalidade
# 2 - Criar alerta para tratamento diferenciado para clientes que tem até 3 ligações no call center para que possa entrar em contato com o objetivo de diminuir as ligações do mesmo 
# 3 - Entrar em contato com clientes que estejam com pagamentos atrasados em 5 dias para negociar , facilitar pagamento , de forma que ele não chegue as 21 dias de atraso
# 4 - Focar em campanhas de marketing para pessoas mais novas que 50 anos
# Com essas ações podemos diminuir a taxa de cancelamento de 56.7% para 12.2%
